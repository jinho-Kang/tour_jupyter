# %%
import numpy as np
import pandas as pd
import time
from tqdm.notebook import tqdm
import folium
import json
import googlemaps

# %%
tour_info = pd.read_csv('data/관광안내소.csv',thousands=',',encoding='cp949')

# %%
tour_info.drop(['데이터기준일자','제공기관코드','제공기관기관명','작업일시',
                '부가서비스정보','평균근무인원수','영어안내가능여부','일본어안내가능여부',
                '중국어안내가능여부','안내가능외국어','안내소위치명','시도명','휴무일',
                '운영기관명','홈페이지주소','소재지지번주소'],axis=1,inplace=True)

# %%
f = open("key/명식key.txt", 'r')
gmaps_key =f.readlines()
gmaps = googlemaps.Client(key=gmaps_key[0])

# %%
tour_info['안내소소개'].fillna('관광안내소', inplace=True)
tour_info['소재지도로명주소'].fillna('관광안내소', inplace=True)
tour_info['소재지도로명주소'][3] = '서울 은평구 불광동 산42-5'
# Out:
# D:\Users\ryh26\jinho\ipykernel_16784\2262639219.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tour_info['소재지도로명주소'][3] = '서울 은평구 불광동 산42-5'

# %%
tour_name = []
for name in tour_info.index:
    tour_name.append(tour_info['관광안내소명'][name])

# %%
for n in tour_info.index:
    if tour_info['소재지도로명주소'][n] == '관광안내소':
        tmp = gmaps.geocode(tour_name, language='ko')
        tour_info['소재지도로명주소'][n] = tmp[0].get('formatted_address')
        tmp_loc = tmp[0].get('geometry')
    else: pass
# Out:
# D:\Users\ryh26\jinho\ipykernel_16784\4173704634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tour_info['소재지도로명주소'][n] = tmp[0].get('formatted_address')

# %%
map = folium.Map(location=[37.5502,126.982], zoom_start=11)

for n in tour_info.index:
        folium.Marker(location=[tour_info['위도'][n],tour_info['경도'][n]],
                    tooltip=tour_info['관광안내소명'][n],popup='<pre>'+tour_info['소재지도로명주소'][n]+'</pre>').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0c631cbe39394c958e5a67106a0f789b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0c631cbe39394c958e5a67106a0f789b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0c631cbe39394c958e5a67106a0f789b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0c631cbe39394c958e5a67106a0f789b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5502%2C%20126.982%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
print(type(tour_info))
tour_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              관광안내소명  시군구명                                              안내소소개  \
# 0          마포관광정보센터   마포구  마포관광정보센터 및 차량이동관광안내소(홍카) 운영을 통해 고품질 관광안내서비스를 제...
# 1          도봉탐방지원센터   도봉구                            도봉산 탐방 정보 안내 및 그린포인트 적립
# 2           북촌마을안내소   종로구                      방문객에게 마을 정보를 제공하고 공익목적의 전시 개최
# 3      불광 둘레길 관광안내소   은평구            북한산 둘레길 은평구(7~10구간) 안내소 주말 운영종료시각 16:00
# 4     구파발 둘레길 관광안내소   은평구            북한산 둘레길 은평구(7~10구간) 안내소 주말 운영종료시각 16:00
# 5    북한산성 둘레길 관광안내소   은평구            북한산 둘레길 은평구(7~10구간) 안내소 주말 운영종료시각 16:00
# 6          강남관광정보센터   강남구  서울 및 강남 주요 관광명소 교통 음식 숙박 행사 관련 최신 정보를 영중일 다국어로 안내
# 7   이태원 역사관광안내소(지하)   용산구                                              관광안내소
# 8          서초관광정보센터   서초구                              코로나19 강남역 임시선별검사소 운영중
# 9         영등포관광정보센터  영등포구                                              관광안내소
# 10          명동관광안내소    중구                                              관광안내소
# 11      서울글로벌문화체험센터    중구                                              관광안내소
# 12         명동관광정보센터    중구                                              관광안내소
# 13         남대문관광안내소    중구                                              관광안내소
# 14         동대문관광안내소    중구                                              관광안내소
# 15        동대문디자인플라자    중구                                              관광안내소
# 16          관광안내전시관    중구                                              관광안내소
# 17              시민청    중구                                              관광안내소
# 18          동대문두산타워    중구                                              관광안내소
# 19           헬로에이피엠    중구                                              관광안내소
# 20          신촌플레이버스  서대문구                                서대문구 관광안내책자 및 지도 제공
# 21        신촌역사관광안내소  서대문구                      신촌역사를 찾는 관광객들에게 서울특별시 관광정보 제공
# 22         송파관광정보센터   송파구                     송파를 찾는 국내외 관광객들에게 관광정보를 제공합니다.
# 23   양천향교역 문화관광 홍보관   강서구                          강서구 문화관광지와 각종행사 및 구정 등 홍보
#
#    운영시작시각(하절기) 운영종료시각(하절기) 운영시작시각(동절기) 운영종료시각(동절기)        안내소전화번호  \
# 0        11:00       20:00       11:00       20:00    02-334-7878
# 1        09:00       18:00       09:00       18:00    02-954-2565
# 2        09:00       18:00       09:00       18:00   02-2148-4161
# 3        08:00       11:00       08:00       11:00    02-351-6505
# 4        08:00       11:00       08:00       11:00    02-351-6505
# 5        08:00       11:00       08:00       11:00    02-351-6505
# 6        10:00       19:00       10:00       19:00   02-3445-0111
# 7        10:00       19:00       10:00       19:00   02-3785-0942
# 8        10:00       20:00       10:00       20:00  0507-1320-126
# 9        10:00       19:00       10:00       19:00   02-2675-5600
# 10       09:00       22:00       09:00       22:00    02-774-3238
# 11       10:30       19:30       10:30       19:30   02-3789-7961
# 12       09:00       17:30       09:00       17:30    02-778-0333
# 13       11:00       17:00       11:00       17:00    02-752-1913
# 14       11:00       21:00       11:00       21:00   02-2236-9135
# 15       11:00       19:00       11:00       19:00   02-2153-0407
# 16       09:00       20:00       09:00       20:00    02-729-9497
# 17       09:00       20:00       09:00       20:00    02-739-7755
# 18       10:30       12:00       10:30       12:00   02-3398-3114
# 19       13:00       19:00       13:00       19:00   02-6388-1369
# 20       11:00       21:00       11:00       21:00  070-4909-9131
# 21       10:00       19:00       10:00       19:00    02-363-7833
# 22       10:00       19:00       10:00       18:00    02-421-0970
# 23       10:00       16:00       10:00       16:00   02-2658-6158
#
#                         소재지도로명주소         위도          경도
# 0             대한민국 서울특별시 마포구 동교동  37.556508  126.926017
# 1              서울특별시 도봉구 도봉산길 73  37.686513  127.037608
# 2             서울특별시 종로구 북촌로5길 48  37.581264  126.983869
# 3               서울 은평구 불광동 산42-5  37.610723  126.939272
# 4   서울특별시 은평구 진관2로 구파발역 2번 출구 인근  37.636348  126.919196
# 5             대한민국 서울특별시 마포구 동교동  37.658250  126.945533
# 6             서울특별시 강남구 압구정로 161  37.526843  127.027059
# 7           용산구 이태원동 지하철6호선 지하 내  37.534616  126.991206
# 8             대한민국 서울특별시 마포구 동교동  37.498183  127.027052
# 9             서울특별시 영등포구 문래로 196  37.517893  126.903777
# 10             서울특별시 중구 명동길 43-1  37.563916  126.984859
# 11              서울특별시 중구 명동8길 27  37.562531  126.985168
# 12                서울특별시 중구 을지로66  37.565155  126.985052
# 13           서울특별시 중구 남대문시장4길 21  37.559185  126.977654
# 14             서울특별시 중구 장충단로 247  37.566802  127.007374
# 15              서울특별시 중구 을지로 281  37.568014  127.010909
# 16              서울특별시 중구 청계천로 40  37.568528  126.981626
# 17             서울특별시 중구 세종대로 110  37.566318  126.977828
# 18             서울특별시 중구 장충단로 275  37.568885  127.008798
# 19             서울특별시 중구 장충단로 253  37.567487  127.008077
# 20          서울특별시 서대문구 연세로 5길 11  37.556622  126.935005
# 21            서울특별시 서대문구 신촌역로 30  37.559831  126.942387
# 22           서울특별시 송파구 송파나루길 206  37.511898  127.104245
# 23             서울특별시 강서구 양천로 341  37.568626  126.840790

# %%
from sqlalchemy import create_engine
import sqlite3
import pymysql

# %%
con = sqlite3.connect('test_db.db')
tour_info.to_sql('test_table2', con)
# Out:
# 24
